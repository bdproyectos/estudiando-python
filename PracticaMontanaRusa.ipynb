# %% [markdown]
# <a href="https://colab.research.google.com/github/bdproyectos/estudiando-python/blob/dev/PracticaMontanaRusa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### La Montaña Rusa
# Los pasajeros deben ser mayores de 15 años para subir

# %%
edad = int(input("Ingresa tu edad"))
varBoolAux = edad >= 15 and edad <=90
if varBoolAux:
    print("Felicidades Puedes subir")
else:
    print("Que lastima, no puedes subir")
# Out:
# Ingresa tu edad91
# Que lastima, no puedes subir
